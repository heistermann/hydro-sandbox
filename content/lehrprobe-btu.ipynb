# %% [markdown]
# # Modellierung der Infiltration und Abflussbildung

# %%
# %pip install -q ipywidgets
# %pip install -q ipympl
# %pip install -q pandas

# %%
from sandboxlib import *
# %matplotlib ipympl
_ = plt.ioff()

# %%
print("Hallo Python.")
# Out:
# Hallo Python.

# %% [markdown]
# ## Das ABC der Abflussmodellierung

# %% [markdown]
# Führe die Funktion `plot_abc_model` aus und untersuche die Aufteilung zwischen Direktabfluss und Basisabfluss in Abhängigkeit der Parameter `a` und `b`. Untersuche die Dynamik des Basisabflusses in Abhängigkeit von Parameter `c`.
#
# **Parameter des abc-Modells**
# - `a`: Anteil des Niederschlag, der ins GW infiltriert
# - `b`: Anteil des Niederschlags, der verdunstet
# - `c`: Anteil des GW-Speichers, der zum Abfluss gelangt
#
# Es muss stets gelt: `a` + `b` <= 1 und `c <= 1`.
#
# Wie hoch würdest Du Parameter `a` für weite Teile Brandenburgs schätzen?

# %%
# Beispiel für eine Niederschlagszeitreihe
P = np.repeat(0,50)
P[[10,12,40]] = 100

# %%
plot_abc_model(P)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# interactive(children=(FloatSlider(value=0.5, description='a', max=1.0, step=0.05), FloatSlider(value=0.2, desc…

# %% [markdown]
# ## Das USGS SCS-CN Verfahren ("Curve-Number-Verfahren")

# %% [markdown]
# Führe die Funktion `plot_cn` aus und erkunde den Einfluss von Bodentyp, Landnutzung, Jahreszeit, Vorereignisniederschlag (P5) und Ereignisniederschlag (P) auf den Abflussbeiwert $\psi$.
#
# **Parameter:**
# - Landnutzung
# - Boden (von `A` für sehr durchlässig bis `D` für undurchlässig)
# - Vegetation (befinden wir uns in der Vegetationsphase - ja oder nein?)
# - P5: Niederschlag der vergangenen 5 Tage (in mm)
# - P: Ereignisniederschlag (mm/d)
#
# Welcher Boden (`A`, `B`, `C` oder `D`) ist typisch für Brandenburg?

# %%
plot_cn()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# interactive(children=(Dropdown(description='Landnutzung', options=('Brache', 'Reihenkulturen', 'Getreide', 'Wi…

# %% [markdown]
# # t.b.c.
